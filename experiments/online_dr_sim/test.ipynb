# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
from vis_utils import plot_poses_2d


fig, ax = plt.subplots()

poses = jnp.array([
    [0.0, 1.0, 0, 0, 0, 0.707, 0.707],   # facing ~90°
    [1.0, 2.0, 0, 0, 0, 0, 1],          # facing 0°
    [1.0, 0.5, 0, 0, 0, -0.707, 0.707], # facing -90°
])

alphas = jnp.array([1.0, 0.5, 0.2])

plot_poses_2d(poses, alphas, ax)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
poses = jnp.array([
    [0.0, 1.0, 0, 0, 0, 0.707, 0.707],   # facing ~90°
    [1.0, 2.0, 0, 0, 0, 0, 1],          # facing 0°
    [1.0, 0.5, 0, 0, 0, -0.707, 0.707], # facing -90°
])
plot_poses_2d(poses, alphas, ax)
plt.show()
